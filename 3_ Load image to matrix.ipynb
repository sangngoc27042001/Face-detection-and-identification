# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
X=[]
y=[]
categories=['not_myface','myface']
for category in categories:
    for img in os.listdir(category):
        real_path=os.path.join(category,img)
        img_array = cv2.imread(real_path)
        new_array = cv2.resize(img_array, (150, 150))
        X.append(new_array)
        label=""
        if(category==categories[0]):
            label=0
        else:
            label=1
        y.append([label])

# %%
X=np.array(X)
X.shape
# Out:
# (13299, 150, 150, 3)

# %%
y=np.array(y)
y.shape
# Out:
# (13299, 1)

# %%
y[1][0]
# Out:
# 0

# %% [markdown]
# # Check the data if there is sth wrong

# %%
import random

# %%
for i in range(20):
    x=random.randint(0,13299)
    plt.imshow(X[x])
    plt.title(categories[y[x][0]])
    plt.show()

# %% [markdown]
# # Save the vectorized data

# %%
import pickle

pickle_out = open("vectorized_data/X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("vectorized_data/y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()
